# %% [markdown]
# <a href="https://colab.research.google.com/github/vanfotis/git-code-playground/blob/main/3210213_ML2025-26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://archive.ics.uci.edu/ml/machine-learning-databases/glass/glass.data
